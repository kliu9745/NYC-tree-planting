# %% [markdown]
# # **Model Setup**

# %%
# install python packages required to solve model
# !pip install pulp
# !pip install gurobipy
from pulp import *
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: pulp in /Applications/anaconda3/lib/python3.11/site-packages (3.1.1)
# Requirement already satisfied: gurobipy in /Applications/anaconda3/lib/python3.11/site-packages (12.0.1)

# %%
# census tract information
ct = pd.read_csv('../data/2023Stocking_2010CT_HVI.csv', index_col = 0)
ct
# Out:
#         OBJECTID       BoroName  BoroCT2010  PUMA  \
# BoroCD
# 1              1  Staten Island     5000900  3903
# 2              2  Staten Island     5002700  3903
# 3              3  Staten Island     5002900  3903
# 4              4  Staten Island     5003300  3903
# 5              5  Staten Island     5003900  3903
# ...          ...            ...         ...   ...
# 2310        2162       Brooklyn     3068600  4009
# 2311        2163       Brooklyn     3069800  4009
# 2312        2164          Bronx     2037600  3702
# 2313        2165          Bronx     2033400  3705
# 2315        2166          Bronx     2042500  3706
#
#                                                NTAName NTACode    Shape_Leng  \
# BoroCD
# 1            West New Brighton-New Brighton-St. George    SI22   7729.016600
# 2                                   Stapleton-Rosebank    SI37   6745.559749
# 3                                   Stapleton-Rosebank    SI37  10895.072440
# 4                        Grymes Hill-Clifton-Fox Hills    SI08  18603.925060
# 5                        Grymes Hill-Clifton-Fox Hills    SI08  11523.702270
# ...                                                ...     ...           ...
# 2310    Georgetown-Marine Park-Bergen Beach-Mill Basin    BK45   6255.090822
# 2311    Georgetown-Marine Park-Bergen Beach-Mill Basin    BK45  27352.744280
# 2312                          Williamsbridge-Olinville    BX44   5797.771749
# 2313                           park-cemetery-etc-Bronx    BX99  32410.142390
# 2315                                           Norwood    BX43   8354.344207
#
#         Borough  ONENYC_HVI  QUINTILES  ... TC2015.stem_count  \
# BoroCD                                  ...
# 1             5   -3.258102          1  ...               269
# 2             5   -0.277956          3  ...               295
# 3             5   -0.450569          3  ...               544
# 4             5   -5.601794          1  ...               354
# 5             5   -6.500620          1  ...               334
# ...         ...         ...        ...  ...               ...
# 2310          3   -1.192089          2  ...               222
# 2311          3    0.088233          3  ...               240
# 2312          2   -0.364435          3  ...               111
# 2313          2   -6.302059          1  ...               272
# 2315          2    0.389436          3  ...               379
#
#        TC2015.stump_count TC2015.stocking_percent_deficit TC2015.max_trees  \
# BoroCD
# 1                       6                        0.236798              381
# 2                      14                        0.056716              323
# 3                       9                        0.447322              767
# 4                      10                        0.798289              825
# 5                       3                        0.236315              478
# ...                   ...                             ...              ...
# 2310                    2                        0.095793              255
# 2311                    4                        0.340751              405
# 2312                    2                        0.235094              185
# 2313                   12                        0.068691              350
# 2315                    9                       -0.196753              423
#
#        TC2015.trees_to_add TC2015.stocking_percent TC2015.trees_to_add_70perc  \
# BoroCD
# 1                      118                0.689928                         83
# 2                       42                 0.86894                         30
# 3                      232                 0.69782                        162
# 4                      481                0.417008                        337
# 5                      147                0.692722                        103
# ...                    ...                     ...                        ...
# 2310                    35                0.862266                         25
# 2311                   169                0.582346                        118
# 2312                    76                0.587843                         53
# 2313                    90                0.742178                         63
# 2315                    53                0.873928                         37
#
#        2023TreesToAdd_70Perc Block_Length_Sum Trees_to_Add_per_1000_Feet
# BoroCD
# 1                       91.0      24481.77128                   3.717051
# 2                       14.0      17279.78767                   0.810195
# 3                      103.6      48612.32223                   2.131147
# 4                      347.2      57694.84794                   6.017868
# 5                      118.3      30316.44182                   3.902173
# ...                      ...              ...                        ...
# 2310                    23.1      15202.01371                   1.519536
# 2311                   113.4      28652.36524                   3.957788
# 2312                    59.5      12219.44297                   4.869289
# 2313                   231.7      20415.69215                  11.349113
# 2315                    54.6      23583.02974                   2.315224
#
# [2166 rows x 23 columns]

# %%
# zone information
zones = pd.read_csv('../data/Zones_Year_Assignment.csv', index_col = 0)
zones.columns = zones.columns.str.strip()
zones.set_index("Unique", inplace = True)
zones
# Out:
#              BoroName  Community Board  Council District  Zone ID  \
# Unique
# 101_1       Manhattan              101                 1        1
# 101_2       Manhattan              101                 1        2
# 101_3       Manhattan              101                 1        3
# 101_4       Manhattan              101                 1        4
# 101_5       Manhattan              101                 1        5
# ...               ...              ...               ...      ...
# 503_2   Staten Island              503                50        2
# 503_3   Staten Island              503                51        3
# 503_4   Staten Island              503                51        4
# 503_5   Staten Island              503                51        5
# 503_6   Staten Island              503                51        6
#
#         Planting Potential  Year  HVI  HVI 4/5 Count  CT Count  \
# Unique
# 101_1                  146     1  1.3              0         1
# 101_2                  141     1  2.7              0         2
# 101_3                  172     4  1.0              0         1
# 101_4                  154     4  1.3              0         8
# 101_5                  249     7  3.0              0         1
# ...                    ...   ...  ...            ...       ...
# 503_2                 1302     3  1.0              0         7
# 503_3                 1295     2  1.0              0         7
# 503_4                 1224     1  1.0              0         4
# 503_5                 1260     9  1.0              0         5
# 503_6                 1147     4  1.0              0         6
#
#        Transition Contract  Transition Overlap %  New Year Assignment
# Unique
# 101_1              MG-124M                   100                    8
# 101_2                    0                     0                    2
# 101_3                    0                     0                    2
# 101_4              MG-124M                    43                    5
# 101_5              MG-124M                   100                    8
# ...                    ...                   ...                  ...
# 503_2                    0                     0                    3
# 503_3                    0                     0                    2
# 503_4                    0                     0                    1
# 503_5                    0                     0                    7
# 503_6                    0                     0                    4
#
# [420 rows x 12 columns]

# %%
# set of zones
I = zones.index.tolist()
print(I)

# set of years in the 9-year cycle
Y = [i for i in range(9)]
print(Y)
# Out:
# ['101_1', '101_2', '101_3', '101_4', '101_5', '101_6', '101_7', '102_1', '102_2', '102_3', '102_4', '102_5', '103_1', '103_2', '103_3', '103_4', '103_5', '103_6', '104_1', '104_2', '104_3', '104_4', '104_5', '105_1', '105_10', '105_11', '105_12', '105_2', '105_3', '105_4', '105_5', '105_6', '105_7', '105_8', '105_9', '106_1', '106_2', '106_3', '106_4', '106_5', '107_1', '107_2', '107_3', '107_4', '108_1', '108_2', '108_3', '108_4', '108_5', '109_1', '109_2', '109_3', '109_4', '110_1', '110_2', '110_3', '111_1', '111_2', '111_3', '111_4', '111_5', '112_1', '112_2', '112_3', '112_4', '112_5', '112_6', '112_7', '201_1', '201_2', '201_3', '201_
# ['102_3', '103_4', '104_3', '104_4', '104_5', '105_10', '105_12', '105_8', '106_5', '109_3', '112_2', '112_3', '112_4', '208_4', '209_1', '209_5', '210_1', '210_10', '211_13', '211_8', '212_1', '212_12', '212_13', '212_15', '212_16', '212_18', '212_7', '301_8', '302_1', '302_7', '305_2', '305_4', '306_2', '311_1', '311_10', '311_8', '313_3', '313_4', '315_11', '318_4', '401_1', '401_3', '403_4', '405_8', '408_1', '408_2', '409_5', '409_6', '410_3', '410_4', '413_16', '414_5']

# %%
min_hvi = zones["HVI"].min()
max_hvi = zones["HVI"].max()

# Scaling function of HVI scores
def hvi_weight(hvi):
    # aggressive
  # return (hvi / 5) ** 3
    # smoother curve
  # return 1 / (1 + np.exp(-(hvi - 3)))
    # HVI has linearly weighted
  return 1 + 4 * (hvi - min_hvi) / (max_hvi - min_hvi)


# time penalty encouraging high-HVI zones to be assigned earlier in the cycle
def time_weight(j):
  n_years = len(Y)
  return np.exp(-0.1 * (j - 1))

# %% [markdown]
# # **Model with HVI-Only Objective (without Strengthened Balance)**

# %%
from ast import keyword
model4 = LpProblem("Tree_Planting_Scheduling", LpMaximize)

# DECISION VARIABLES
  # x[i,j] = 1 if zone i is assigned to year j
x = {(i, j): LpVariable(f"x_{i}_{j}", cat="Binary") for i in I for j in Y}

  # p[i,j] is the # of trees planted in zone i in year j
p = {
    (i, j): LpVariable(f"p_{i}_{j}", lowBound=0, upBound=planning_potentials[i])
    for i in I for j in Y
}
  # dictionary mapping each year to how much the # of assigned zones in that
  # year deviates from the expected number (total zones / total years)
deviation_vars = {
    j: LpVariable(f"tree_dev_{j}", lowBound=0)
    for j in Y[:-1]  # no deviation after the last year
}

# CONSTRAINTS

# 1. Each zone must be scheduled exactly once across 9 years
for i in I:
    model4 += lpSum(x[i, j] for j in Y) == 1, f"VisitOnce_{i}"

# 2. CB-Year tree capacity constraint (≤1299 trees per CB per year)
unique_cbs = set(community_boards.values())
for cb in unique_cbs:
    cb_tracts = [i for i in I if community_boards[i] == cb]
    for j in Y:
        model4 += (
            lpSum(p[i,j] for i in cb_tracts) <= 1299,
            f"Capacity_CB{cb}_Year{j}"
        )

# 2.5. Handle CBs that exceed the 1300 limit
# PLEASE ADJUST overflow_cbs TO DATA
overflow_cbs = [412, 413, 414, 502, 503]

# Binary overflow flags
overflow_cb_var = {(cb, j): LpVariable(f"overflow_{cb}_{j}", cat="Binary")
               for cb in overflow_cbs for j in Y}

# Allow 1300 + delta if overflow_cb is used

# PLEASE ADJUST delta
delta = 1000
for cb in [412, 413, 414, 502, 503]:
    cb_tracts = [i for i in I if community_boards[i] == cb]
    for j in Y:
        model4 += (
            lpSum(p[i,j] for i in cb_tracts) <= 1299 + delta * overflow_cb_var[(cb, j)]
        )

# At most 1 CB overflow per year
for j in Y:
    model4 += lpSum(overflow_cb_var[(cb, j)] for cb in [412, 413, 414, 502, 503]) <= 1


# 3. Trees can only be planted in a given zone in a given year if it is assigned to that year
for i in I:
  for j in Y:
    model4 += p[i,j] <= planning_potentials[i] * x[i,j]


# 4. Visit at least one zone in one CB in every 3 years in the cycle
cb_set = set(community_boards.values())
for cb in cb_set:
    cb_tracts = [i for i in I if community_boards[i] == cb]
    if len(cb_tracts) > 2:
      for start in [0,3,6]:
        three_y_block = range(start, start+3)
        model4 += lpSum(x[i,j] for i in cb_tracts for j in three_y_block) >= 1
    else:
      model4 += lpSum(x[i,j] for i in cb_tracts for j in Y) == len(cb_tracts)


# 5. Balance constraint in # of Trees Planted
trees_per_year = {
    j: lpSum(p[i, j] for i in I)
    for j in Y
}

for j in Y:
  # cannot plant more than 20000 trees per year
  model4 += trees_per_year[j] <= 20000
  # best not to plant below 5000 trees per year, can change
  model4 += trees_per_year[j] >= 5000

for j in Y[:-1]:
    model4 += trees_per_year[j + 1] - trees_per_year[j] <= deviation_vars[j]
    model4 += trees_per_year[j] - trees_per_year[j + 1] <= deviation_vars[j]

# hard cap on the total deviation between all years
model4 += lpSum(deviation_vars.values()) <= 10000

# target_trees_per_year = 18000
# for j in Y:
#     deviation = deviation_vars[j]
#     assigned_trees = lpSum(p[i, j] for i in I)
#     model4 += (assigned_trees - target_trees_per_year <= 2000), f"Tree_Dev_Pos_{j}"

#     deviation >= assigned_trees - target_trees_per_year

# 6. For each zone, if it was visited within the last 'cooldown' years in the previous cycle,
# cannot plant it in the first 'cooldown - (9 - y_last)' years of the current cycle

# cooldown period in years
cooldown = 5

for unique_id, row in zones.iterrows():
  if pd.isnull(row["New Year Assignment"]):
        print(f"⏭️ Zone {i} skipped due to missing prior assignment")
        continue
  y_last = int(row["New Year Assignment"]) - 1
  earliest_allowed_year = min(8, y_last + cooldown - 9)

  if earliest_allowed_year > 8:
    print(f"⚠️ Zone {i}: Cooldown ends in year {earliest_allowed_year + 1}, beyond planning horizon.")

  for j in Y:
    if earliest_allowed_year > 8:
      print(f"⚠️ Zone {i} cannot be scheduled due to cooldown ending after last year.")
    if j < earliest_allowed_year:
      model4 += x[unique_id, j] == 0
      model4 += p[unique_id, j] == 0

# OBJECTIVE
model4 += lpSum(
    hvi_weight(hvi_scores[i]) * time_weight(j) * p[i, j]
    for i in I for j in Y
), "Maximize_HVI"

# SOLVE
from pulp import PULP_CBC_CMD
model4.solve(PULP_CBC_CMD(msg=True, timeLimit=600))
if LpStatus[model4.status] != "Optimal":
    print("WARNING: No feasible solution found. Status =", LpStatus[model4.status])
else:
    print("Optimal solution found! Objective =", value(model4.objective))

zones_per_year = np.zeros(9)
for var in model4.variables():
    if var.varValue is not None and var.varValue > 1e-10:
        name = var.name
        parts = name.split('_')
        var_type = parts[0]
        year = parts[-1]
        shifted_year = str(int(year) + 1)
        tract_id = "_".join(parts[1:-1])
        if var_type == "p":
          print(f"Census Tract: {tract_id} is assigned to Year: {shifted_year}, {round(var.varValue)} trees to plant")
        else:
          zones_per_year[int(year)] += 1
# Out:
# Optimal solution found! Objective = 346073.35563958954
# Census Tract: 101_1 is assigned to Year: 5, 146 trees to plant
# Census Tract: 101_2 is assigned to Year: 2, 141 trees to plant
# Census Tract: 101_3 is assigned to Year: 9, 172 trees to plant
# Census Tract: 101_4 is assigned to Year: 6, 154 trees to plant
# Census Tract: 101_5 is assigned to Year: 4, 249 trees to plant
# Census Tract: 101_6 is assigned to Year: 3, 128 trees to plant
# Census Tract: 101_7 is assigned to Year: 2, 97 trees to plant
# Census Tract: 102_1 is assigned to Year: 8, 131 trees to plant
# Census Tract: 102_2 is assigned to Year: 2, 151 trees to plant
# Census Tract: 102_3 is assigned to Year: 1, 160 trees to plant
# Census Tract: 102_4 is assigned to Year: 4, 141 trees to plant
# Census Tract: 102_5 is assigned to Year: 3, 151 trees to plant
# Census Tract: 103_1 is assigned to Year: 4, 136 trees to plant
# Census Tract: 103_2 is assigned to Year: 2, 145 trees to plant
# Census Tract: 103_3 is assigned to Year: 1, 143 trees to plant
# Census Tract: 103_4 is assigned to Year: 2, 134 trees to plant
# Census Tract: 103_5 is assigned to Year: 2, 138 trees to plant
# Census Tract: 103_6 is assigned to Year: 8, 151 trees to plant
# Census Tract: 104_1 is assigned to Year: 2, 133 trees to plant
# Census Tract: 104_2 is assigned to Year: 5, 130 trees to plant
# Census Tract: 104_3 is assigned to Year: 7, 130 trees to plant
# Census Tract: 104_4 is assigned to Year: 1, 115 trees to plant
# Census Tract: 104_5 is assigned to Year: 2, 135 trees to plant
# Census Tract: 105_10 is assigned to Year: 2, 112 trees to plant
# Census Tract: 105_11 is assigned to Year: 3, 118 trees to plant
# Census Tract: 105_12 is assigned to Year: 3, 135 trees to plant
# Census Tract: 105_1 is assigned to Year: 3, 140 trees to plant
# Census Tract: 105_2 is assigned to Year: 8, 156 trees to plant
# Census Tract: 105_3 is assigned to Year: 2, 166 trees to plant
# Census Tract: 105_4 is assigned to Year: 2, 165 trees to plant
# Census Tract: 105_5 is assigned to Year: 2, 149 trees to plant
# Census Tract: 105_6 is assigned to Year: 3, 152 trees to plant
# Census Tract: 105_7 is assigned to Year: 3, 143 trees to plant
# Census Tract: 105_8 is assigned to Year: 3, 203 trees to plant
# Census Tract: 105_9 is assigned to Year: 5, 152 trees to plant
# Census Tract: 106_1 is assigned to Year: 3, 127 trees to plant
# Census Tract: 106_2 is assigned to Year: 8, 131 trees to plant
# Census Tract: 106_3 is assigned to Year: 4, 137 trees to plant
# Census Tract: 106_4 is assigned to Year: 2, 103 trees to plant
# Census Tract: 106_5 is assigned to Year: 3, 99 trees to plant
# Census Tract: 107_1 is assigned to Year: 5, 140 trees to plant
# Census Tract: 107_2 is assigned to Year: 8, 137 trees to plant
# Census Tract: 107_3 is assigned to Year: 5, 150 trees to plant
# Census Tract: 107_4 is assigned to Year: 3, 145 trees to plant
# Census Tract: 108_1 is assigned to Year: 3, 135 trees to plant
# Census Tract: 108_2 is assigned to Year: 5, 110 trees to plant
# Census Tract: 108_3 is assigned to Year: 3, 144 trees to plant
# Census Tract: 108_4 is assigned to Year: 8, 107 trees to plant
# Census Tract: 108_5 is assigned to Year: 3, 97 trees to plant
# Census Tract: 109_1 is assigned to Year: 2, 134 trees to plant
# Census Tract: 109_2 is assigned to Year: 1, 136 trees to plant
# Census Tract: 109_3 is assigned to Year: 4, 130 trees to plant
# Census Tract: 109_4 is assigned to Year: 8, 121 trees to plant
# Census Tract: 110_1 is assigned to Year: 4, 142 trees to plant
# Census Tract: 110_2 is assigned to Year: 1, 147 trees to plant
# Census Tract: 110_3 is assigned to Year: 7, 141 trees to plant
# Census Tract: 111_1 is assigned to Year: 1, 139 trees to plant
# Census Tract: 111_2 is assigned to Year: 7, 138 trees to plant
# Census Tract: 111_3 is assigned to Year: 4, 140 trees to plant
# Census Tract: 111_4 is assigned to Year: 1, 146 trees to plant
# Census Tract: 111_5 is assigned to Year: 2, 147 trees to plant
# Census Tract: 112_1 is assigned to Year: 5, 137 trees to plant
# Census Tract: 112_2 is assigned to Year: 7, 129 trees to plant
# Census Tract: 112_3 is assigned to Year: 3, 138 trees to plant
# Census Tract: 112_4 is assigned to Year: 2, 144 trees to plant
# Census Tract: 112_5 is assigned to Year: 1, 130 trees to plant
# Census Tract: 112_6 is assigned to Year: 2, 142 trees to plant
# Census Tract: 112_7 is assigned to Year: 3, 114 trees to plant
# Census Tract: 201_1 is assigned to Year: 4, 147 trees to plant
# Census Tract: 201_2 is assigned to Year: 7, 149 trees to plant
# Census Tract: 201_3 is assigned to Year: 1, 145 trees to plant
# Census Tract: 201_4 is assigned to Year: 1, 139 trees to plant
# Census Tract: 202_1 is assigned to Year: 3, 148 trees to plant
# Census Tract: 202_2 is assigned to Year: 1, 127 trees to plant
# Census Tract: 203_2 is assigned to Year: 2, 148 trees to plant
# Census Tract: 203_3 is assigned to Year: 2, 152 trees to plant
# Census Tract: 203_4 is assigned to Year: 4, 87 trees to plant
# Census Tract: 204_1 is assigned to Year: 7, 168 trees to plant
# Census Tract: 204_2 is assigned to Year: 1, 160 trees to plant
# Census Tract: 204_3 is assigned to Year: 5, 161 trees to plant
# Census Tract: 204_4 is assigned to Year: 2, 164 trees to plant
# Census Tract: 205_1 is assigned to Year: 1, 147 trees to plant
# Census Tract: 205_2 is assigned to Year: 4, 114 trees to plant
# Census Tract: 205_3 is assigned to Year: 7, 132 trees to plant
# Census Tract: 206_1 is assigned to Year: 7, 152 trees to plant
# Census Tract: 206_2 is assigned to Year: 4, 116 trees to plant
# Census Tract: 206_3 is assigned to Year: 1, 126 trees to plant
# Census Tract: 207_1 is assigned to Year: 4, 149 trees to plant
# Census Tract: 207_2 is assigned to Year: 1, 153 trees to plant
# Census Tract: 207_3 is assigned to Year: 1, 147 trees to plant
# Census Tract: 207_4 is assigned to Year: 7, 150 trees to plant
# Census Tract: 207_5 is assigned to Year: 1, 144 trees to plant
# Census Tract: 208_11 is assigned to Year: 6, 217 trees to plant
# Census Tract: 208_1 is assigned to Year: 3, 227 trees to plant
# Census Tract: 208_2 is assigned to Year: 5, 181 trees to plant
# Census Tract: 208_3 is assigned to Year: 5, 157 trees to plant
# Census Tract: 208_4 is assigned to Year: 2, 191 trees to plant
# Census Tract: 208_5 is assigned to Year: 5, 148 trees to plant
# Census Tract: 208_6 is assigned to Year: 6, 175 trees to plant
# Census Tract: 208_7 is assigned to Year: 2, 166 trees to plant
# Census Tract: 208_8 is assigned to Year: 6, 177 trees to plant
# Census Tract: 208_9 is assigned to Year: 1, 128 trees to plant
# Census Tract: 209_10 is assigned to Year: 7, 168 trees to plant
# Census Tract: 209_1 is assigned to Year: 4, 171 trees to plant
# Census Tract: 209_2 is assigned to Year: 1, 176 trees to plant
# Census Tract: 209_3 is assigned to Year: 1, 180 trees to plant
# Census Tract: 209_4 is assigned to Year: 1, 162 trees to plant
# Census Tract: 209_5 is assigned to Year: 4, 165 trees to plant
# Census Tract: 209_6 is assigned to Year: 1, 136 trees to plant
# Census Tract: 209_7 is assigned to Year: 1, 151 trees to plant
# Census Tract: 209_8 is assigned to Year: 1, 147 trees to plant
# Census Tract: 209_9 is assigned to Year: 1, 149 trees to plant
# Census Tract: 210_10 is assigned to Year: 4, 175 trees to plant
# Census Tract: 210_11 is assigned to Year: 9, 97 trees to plant
# Census Tract: 210_12 is assigned to Year: 1, 226 trees to plant
# Census Tract: 210_1 is assigned to Year: 2, 182 trees to plant
# Census Tract: 210_2 is assigned to Year: 2, 147 trees to plant
# Census Tract: 210_3 is assigned to Year: 5, 155 trees to plant
# Census Tract: 210_4 is assigned to Year: 2, 172 trees to plant
# Census Tract: 210_5 is assigned to Year: 1, 171 trees to plant
# Census Tract: 210_6 is assigned to Year: 1, 173 trees to plant
# Census Tract: 210_7 is assigned to Year: 4, 246 trees to plant
# Census Tract: 210_8 is assigned to Year: 5, 160 trees to plant
# Census Tract: 210_9 is assigned to Year: 1, 165 trees to plant
# Census Tract: 211_10 is assigned to Year: 3, 147 trees to plant
# Census Tract: 211_11 is assigned to Year: 3, 148 trees to plant
# Census Tract: 211_12 is assigned to Year: 9, 130 trees to plant
# Census Tract: 211_13 is assigned to Year: 1, 136 trees to plant
# Census Tract: 211_14 is assigned to Year: 1, 129 trees to plant
# Census Tract: 211_15 is assigned to Year: 1, 123 trees to plant
# Census Tract: 211_1 is assigned to Year: 2, 165 trees to plant
# Census Tract: 211_2 is assigned to Year: 1, 150 trees to plant
# Census Tract: 211_3 is assigned to Year: 2, 162 trees to plant
# Census Tract: 211_4 is assigned to Year: 3, 202 trees to plant
# Census Tract: 211_5 is assigned to Year: 5, 154 trees to plant
# Census Tract: 211_6 is assigned to Year: 1, 161 trees to plant
# Census Tract: 211_7 is assigned to Year: 3, 155 trees to plant
# Census Tract: 211_8 is assigned to Year: 3, 169 trees to plant
# Census Tract: 211_9 is assigned to Year: 2, 178 trees to plant
# Census Tract: 212_10 is assigned to Year: 1, 271 trees to plant
# Census Tract: 212_11 is assigned to Year: 2, 160 trees to plant
# Census Tract: 212_12 is assigned to Year: 2, 149 trees to plant
# Census Tract: 212_13 is assigned to Year: 5, 163 trees to plant
# Census Tract: 212_14 is assigned to Year: 5, 344 trees to plant
# Census Tract: 212_15 is assigned to Year: 5, 174 trees to plant
# Census Tract: 212_16 is assigned to Year: 5, 199 trees to plant
# Census Tract: 212_17 is assigned to Year: 7, 156 trees to plant
# Census Tract: 212_18 is assigned to Year: 5, 90 trees to plant
# Census Tract: 212_1 is assigned to Year: 2, 152 trees to plant
# Census Tract: 212_2 is assigned to Year: 1, 161 trees to plant
# Census Tract: 212_3 is assigned to Year: 1, 147 trees to plant
# Census Tract: 212_4 is assigned to Year: 1, 167 trees to plant
# Census Tract: 212_5 is assigned to Year: 5, 149 trees to plant
# Census Tract: 212_6 is assigned to Year: 2, 162 trees to plant
# Census Tract: 212_7 is assigned to Year: 1, 260 trees to plant
# Census Tract: 212_8 is assigned to Year: 2, 194 trees to plant
# Census Tract: 212_9 is assigned to Year: 1, 179 trees to plant
# Census Tract: 301_1 is assigned to Year: 2, 204 trees to plant
# Census Tract: 301_2 is assigned to Year: 2, 194 trees to plant
# Census Tract: 301_3 is assigned to Year: 2, 205 trees to plant
# Census Tract: 301_4 is assigned to Year: 1, 196 trees to plant
# Census Tract: 301_5 is assigned to Year: 1, 190 trees to plant
# Census Tract: 301_6 is assigned to Year: 5, 193 trees to plant
# Census Tract: 301_7 is assigned to Year: 5, 189 trees to plant
# Census Tract: 301_8 is assigned to Year: 7, 179 trees to plant
# Census Tract: 302_1 is assigned to Year: 7, 220 trees to plant
# Census Tract: 302_2 is assigned to Year: 4, 199 trees to plant
# Census Tract: 302_3 is assigned to Year: 3, 238 trees to plant
# Census Tract: 302_4 is assigned to Year: 2, 202 trees to plant
# Census Tract: 302_5 is assigned to Year: 2, 223 trees to plant
# Census Tract: 302_6 is assigned to Year: 2, 217 trees to plant
# Census Tract: 302_7 is assigned to Year: 2, 185 trees to plant
# Census Tract: 303_1 is assigned to Year: 4, 192 trees to plant
# Census Tract: 303_2 is assigned to Year: 7, 192 trees to plant
# Census Tract: 303_3 is assigned to Year: 1, 149 trees to plant
# Census Tract: 303_4 is assigned to Year: 1, 139 trees to plant
# Census Tract: 304_1 is assigned to Year: 2, 200 trees to plant
# Census Tract: 304_2 is assigned to Year: 4, 133 trees to plant
# Census Tract: 304_3 is assigned to Year: 7, 145 trees to plant
# Census Tract: 305_10 is assigned to Year: 4, 192 trees to plant
# Census Tract: 305_11 is assigned to Year: 2, 143 trees to plant
# Census Tract: 305_12 is assigned to Year: 4, 170 trees to plant
# Census Tract: 305_1 is assigned to Year: 4, 194 trees to plant
# Census Tract: 305_2 is assigned to Year: 7, 218 trees to plant
# Census Tract: 305_3 is assigned to Year: 1, 196 trees to plant
# Census Tract: 305_4 is assigned to Year: 1, 201 trees to plant
# Census Tract: 305_5 is assigned to Year: 1, 228 trees to plant
# Census Tract: 305_6 is assigned to Year: 4, 200 trees to plant
# Census Tract: 305_7 is assigned to Year: 1, 190 trees to plant
# Census Tract: 305_8 is assigned to Year: 2, 209 trees to plant
# Census Tract: 305_9 is assigned to Year: 4, 191 trees to plant
# Census Tract: 306_1 is assigned to Year: 3, 207 trees to plant
# Census Tract: 306_2 is assigned to Year: 7, 206 trees to plant
# Census Tract: 306_3 is assigned to Year: 2, 212 trees to plant
# Census Tract: 306_4 is assigned to Year: 4, 223 trees to plant
# Census Tract: 307_1 is assigned to Year: 1, 186 trees to plant
# Census Tract: 307_2 is assigned to Year: 1, 153 trees to plant
# Census Tract: 307_3 is assigned to Year: 4, 194 trees to plant
# Census Tract: 307_4 is assigned to Year: 7, 163 trees to plant
# Census Tract: 308_1 is assigned to Year: 4, 190 trees to plant
# Census Tract: 308_2 is assigned to Year: 1, 139 trees to plant
# Census Tract: 308_3 is assigned to Year: 7, 129 trees to plant
# Census Tract: 309_1 is assigned to Year: 1, 190 trees to plant
# Census Tract: 309_2 is assigned to Year: 7, 183 trees to plant
# Census Tract: 309_3 is assigned to Year: 4, 183 trees to plant
# Census Tract: 310_1 is assigned to Year: 2, 198 trees to plant
# Census Tract: 310_2 is assigned to Year: 2, 194 trees to plant
# Census Tract: 310_3 is assigned to Year: 3, 209 trees to plant
# Census Tract: 310_4 is assigned to Year: 5, 194 trees to plant
# Census Tract: 310_5 is assigned to Year: 3, 206 trees to plant
# Census Tract: 310_6 is assigned to Year: 5, 197 trees to plant
# Census Tract: 310_7 is assigned to Year: 4, 196 trees to plant
# Census Tract: 310_8 is assigned to Year: 9, 194 trees to plant
# Census Tract: 311_10 is assigned to Year: 2, 183 trees to plant
# Census Tract: 311_1 is assigned to Year: 7, 207 trees to plant
# Census Tract: 311_2 is assigned to Year: 5, 198 trees to plant
# Census Tract: 311_3 is assigned to Year: 1, 222 trees to plant
# Census Tract: 311_4 is assigned to Year: 1, 215 trees to plant
# Census Tract: 311_5 is assigned to Year: 3, 205 trees to plant
# Census Tract: 311_6 is assigned to Year: 2, 216 trees to plant
# Census Tract: 311_7 is assigned to Year: 2, 215 trees to plant
# Census Tract: 311_8 is assigned to Year: 5, 213 trees to plant
# Census Tract: 311_9 is assigned to Year: 3, 225 trees to plant
# Census Tract: 312_1 is assigned to Year: 1, 202 trees to plant
# Census Tract: 312_2 is assigned to Year: 1, 195 trees to plant
# Census Tract: 312_3 is assigned to Year: 5, 201 trees to plant
# Census Tract: 312_4 is assigned to Year: 1, 206 trees to plant
# Census Tract: 312_5 is assigned to Year: 2, 201 trees to plant
# Census Tract: 312_6 is assigned to Year: 2, 195 trees to plant
# Census Tract: 312_7 is assigned to Year: 7, 203 trees to plant
# Census Tract: 313_1 is assigned to Year: 7, 215 trees to plant
# Census Tract: 313_2 is assigned to Year: 4, 205 trees to plant
# Census Tract: 313_3 is assigned to Year: 2, 191 trees to plant
# Census Tract: 313_4 is assigned to Year: 2, 189 trees to plant
# Census Tract: 313_5 is assigned to Year: 1, 194 trees to plant
# Census Tract: 313_6 is assigned to Year: 1, 233 trees to plant
# Census Tract: 313_7 is assigned to Year: 1, 212 trees to plant
# Census Tract: 314_1 is assigned to Year: 5, 191 trees to plant
# Census Tract: 314_2 is assigned to Year: 1, 192 trees to plant
# Census Tract: 314_3 is assigned to Year: 1, 147 trees to plant
# Census Tract: 314_4 is assigned to Year: 2, 171 trees to plant
# Census Tract: 314_5 is assigned to Year: 2, 207 trees to plant
# Census Tract: 314_6 is assigned to Year: 7, 159 trees to plant
# Census Tract: 315_10 is assigned to Year: 3, 207 trees to plant
# Census Tract: 315_11 is assigned to Year: 4, 124 trees to plant
# Census Tract: 315_12 is assigned to Year: 2, 130 trees to plant
# Census Tract: 315_13 is assigned to Year: 8, 128 trees to plant
# Census Tract: 315_1 is assigned to Year: 5, 800 trees to plant
# Census Tract: 315_2 is assigned to Year: 4, 220 trees to plant
# Census Tract: 315_3 is assigned to Year: 2, 205 trees to plant
# Census Tract: 315_4 is assigned to Year: 2, 205 trees to plant
# Census Tract: 315_5 is assigned to Year: 4, 193 trees to plant
# Census Tract: 315_6 is assigned to Year: 2, 189 trees to plant
# Census Tract: 315_7 is assigned to Year: 4, 232 trees to plant
# Census Tract: 315_8 is assigned to Year: 5, 191 trees to plant
# Census Tract: 315_9 is assigned to Year: 3, 203 trees to plant
# Census Tract: 316_1 is assigned to Year: 4, 162 trees to plant
# Census Tract: 316_2 is assigned to Year: 1, 190 trees to plant
# Census Tract: 316_3 is assigned to Year: 7, 152 trees to plant
# Census Tract: 317_1 is assigned to Year: 7, 191 trees to plant
# Census Tract: 317_2 is assigned to Year: 4, 209 trees to plant
# Census Tract: 317_3 is assigned to Year: 1, 189 trees to plant
# Census Tract: 317_4 is assigned to Year: 1, 203 trees to plant
# Census Tract: 317_5 is assigned to Year: 1, 198 trees to plant
# Census Tract: 317_6 is assigned to Year: 1, 198 trees to plant
# Census Tract: 317_7 is assigned to Year: 1, 191 trees to plant
# Census Tract: 317_8 is assigned to Year: 1, 186 trees to plant
# Census Tract: 318_10 is assigned to Year: 1, 243 trees to plant
# Census Tract: 318_11 is assigned to Year: 1, 211 trees to plant
# Census Tract: 318_12 is assigned to Year: 2, 243 trees to plant
# Census Tract: 318_13 is assigned to Year: 2, 204 trees to plant
# Census Tract: 318_14 is assigned to Year: 7, 221 trees to plant
# Census Tract: 318_15 is assigned to Year: 4, 221 trees to plant
# Census Tract: 318_16 is assigned to Year: 3, 220 trees to plant
# Census Tract: 318_17 is assigned to Year: 1, 159 trees to plant
# Census Tract: 318_18 is assigned to Year: 3, 211 trees to plant
# Census Tract: 318_1 is assigned to Year: 2, 216 trees to plant
# Census Tract: 318_2 is assigned to Year: 2, 217 trees to plant
# Census Tract: 318_3 is assigned to Year: 2, 202 trees to plant
# Census Tract: 318_4 is assigned to Year: 3, 226 trees to plant
# Census Tract: 318_5 is assigned to Year: 1, 211 trees to plant
# Census Tract: 318_6 is assigned to Year: 3, 196 trees to plant
# Census Tract: 318_7 is assigned to Year: 3, 221 trees to plant
# Census Tract: 318_8 is assigned to Year: 1, 228 trees to plant
# Census Tract: 318_9 is assigned to Year: 1, 231 trees to plant
# Census Tract: 401_1 is assigned to Year: 2, 540 trees to plant
# Census Tract: 401_2 is assigned to Year: 4, 546 trees to plant
# Census Tract: 401_3 is assigned to Year: 7, 542 trees to plant
# Census Tract: 401_4 is assigned to Year: 3, 402 trees to plant
# Census Tract: 401_5 is assigned to Year: 1, 423 trees to plant
# Census Tract: 402_1 is assigned to Year: 4, 553 trees to plant
# Census Tract: 402_2 is assigned to Year: 1, 562 trees to plant
# Census Tract: 402_3 is assigned to Year: 7, 494 trees to plant
# Census Tract: 402_4 is assigned to Year: 1, 500 trees to plant
# Census Tract: 403_1 is assigned to Year: 4, 643 trees to plant
# Census Tract: 403_2 is assigned to Year: 1, 621 trees to plant
# Census Tract: 403_3 is assigned to Year: 2, 620 trees to plant
# Census Tract: 403_4 is assigned to Year: 7, 531 trees to plant
# Census Tract: 404_1 is assigned to Year: 1, 609 trees to plant
# Census Tract: 404_2 is assigned to Year: 1, 635 trees to plant
# Census Tract: 404_3 is assigned to Year: 4, 596 trees to plant
# Census Tract: 404_4 is assigned to Year: 7, 544 trees to plant
# Census Tract: 405_1 is assigned to Year: 3, 562 trees to plant
# Census Tract: 405_2 is assigned to Year: 2, 589 trees to plant
# Census Tract: 405_3 is assigned to Year: 1, 403 trees to plant
# Census Tract: 405_4 is assigned to Year: 5, 562 trees to plant
# Census Tract: 405_5 is assigned to Year: 9, 555 trees to plant
# Census Tract: 405_6 is assigned to Year: 4, 546 trees to plant
# Census Tract: 405_7 is assigned to Year: 3, 564 trees to plant
# Census Tract: 405_8 is assigned to Year: 2, 568 trees to plant
# Census Tract: 406_1 is assigned to Year: 3, 547 trees to plant
# Census Tract: 406_2 is assigned to Year: 9, 538 trees to plant
# Census Tract: 406_3 is assigned to Year: 5, 473 trees to plant
# Census Tract: 406_4 is assigned to Year: 5, 422 trees to plant
# Census Tract: 407_10 is assigned to Year: 8, 541 trees to plant
# Census Tract: 407_11 is assigned to Year: 9, 603 trees to plant
# Census Tract: 407_1 is assigned to Year: 6, 558 trees to plant
# Census Tract: 407_2 is assigned to Year: 8, 544 trees to plant
# Census Tract: 407_3 is assigned to Year: 3, 569 trees to plant
# Census Tract: 407_4 is assigned to Year: 5, 550 trees to plant
# Census Tract: 407_5 is assigned to Year: 5, 453 trees to plant
# Census Tract: 407_6 is assigned to Year: 3, 577 trees to plant
# Census Tract: 407_7 is assigned to Year: 9, 552 trees to plant
# Census Tract: 407_8 is assigned to Year: 6, 600 trees to plant
# Census Tract: 407_9 is assigned to Year: 4, 669 trees to plant
# Census Tract: 408_10 is assigned to Year: 6, 590 trees to plant
# Census Tract: 408_1 is assigned to Year: 3, 558 trees to plant
# Census Tract: 408_2 is assigned to Year: 5, 627 trees to plant
# Census Tract: 408_3 is assigned to Year: 6, 567 trees to plant
# Census Tract: 408_4 is assigned to Year: 9, 391 trees to plant
# Census Tract: 408_5 is assigned to Year: 9, 657 trees to plant
# Census Tract: 408_6 is assigned to Year: 4, 641 trees to plant
# Census Tract: 408_7 is assigned to Year: 8, 505 trees to plant
# Census Tract: 408_8 is assigned to Year: 5, 602 trees to plant
# Census Tract: 408_9 is assigned to Year: 4, 630 trees to plant
# Census Tract: 409_1 is assigned to Year: 2, 542 trees to plant
# Census Tract: 409_2 is assigned to Year: 3, 556 trees to plant
# Census Tract: 409_3 is assigned to Year: 5, 556 trees to plant
# Census Tract: 413_4 is assigned to Year: 4, 593 trees to plant
# Census Tract: 413_5 is assigned to Year: 5, 649 trees to plant
# Census Tract: 413_6 is assigned to Year: 4, 568 trees to plant
# Census Tract: 413_7 is assigned to Year: 5, 626 trees to plant
# Census Tract: 413_8 is assigned to Year: 9, 563 trees to plant
# Census Tract: 413_9 is assigned to Year: 9, 690 trees to plant
# Census Tract: 414_1 is assigned to Year: 2, 597 trees to plant
# Census Tract: 414_2 is assigned to Year: 3, 625 trees to plant
# Census Tract: 414_3 is assigned to Year: 3, 674 trees to plant
# Census Tract: 414_4 is assigned to Year: 1, 652 trees to plant
# Census Tract: 414_5 is assigned to Year: 4, 569 trees to plant
# Census Tract: 414_6 is assigned to Year: 8, 587 trees to plant
# Census Tract: 501_1 is assigned to Year: 6, 1220 trees to plant
# Census Tract: 501_2 is assigned to Year: 9, 1191 trees to plant
# Census Tract: 501_3 is assigned to Year: 4, 1259 trees to plant
# Census Tract: 501_4 is assigned to Year: 8, 1168 trees to plant
# Census Tract: 501_5 is assigned to Year: 3, 1211 trees to plant
# Census Tract: 501_6 is assigned to Year: 5, 1149 trees to plant
# Census Tract: 501_7 is assigned to Year: 2, 1267 trees to plant
# Census Tract: 502_1 is assigned to Year: 5, 1299 trees to plant
# Census Tract: 502_2 is assigned to Year: 8, 1299 trees to plant
# Census Tract: 502_3 is assigned to Year: 9, 1299 trees to plant
# Census Tract: 502_4 is assigned to Year: 7, 1258 trees to plant
# Census Tract: 502_5 is assigned to Year: 6, 1167 trees to plant
# Census Tract: 502_6 is assigned to Year: 4, 1186 trees to plant
# Census Tract: 502_7 is assigned to Year: 3, 833 trees to plant
# Census Tract: 503_1 is assigned to Year: 9, 1196 trees to plant
# Census Tract: 503_2 is assigned to Year: 6, 1299 trees to plant
# Census Tract: 503_3 is assigned to Year: 5, 1295 trees to plant
# Census Tract: 503_4 is assigned to Year: 4, 1224 trees to plant
# Census Tract: 503_5 is assigned to Year: 8, 1260 trees to plant
# Census Tract: 503_6 is assigned to Year: 3, 870 trees to plant

# %%
import matplotlib.pyplot as plt

assignments = []
for i in I:
    for j in Y:
        var = x[i,j]
        if var.varValue is not None and var.varValue > 0.5:
            assignments.append((i, j, hvi_scores[i]))

df_assign = pd.DataFrame(assignments, columns=['Tract', 'Year', 'HVI'])

hvi_per_year = df_assign.groupby('Year')['HVI'].sum().reset_index()
hvi_per_year['Year_adj'] = hvi_per_year['Year'] + 1
plt.figure(figsize=(10,6))
plt.bar(hvi_per_year['Year_adj'], hvi_per_year['HVI'], color='orange', alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Total Heat Vulnerability Index (HVI)')
plt.title('Total HVI Impact From Census Tracts Assigned per Year (HVI-Only Model, Obj. has linear hvi_weight and # of trees)')
plt.xticks(hvi_per_year['Year_adj'])
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
plt.bar(hvi_per_year['Year_adj'], zones_per_year, color='blue', alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Zones per Year')
plt.title('Number of Zones Assigned to Each Year (HVI-Only Model, Obj. has non-linear hvi_weight and # of trees)')
plt.xticks(hvi_per_year['Year_adj'])
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
tree_totals = np.zeros(len(Y))
for (i, j) in p:
    if p[i, j].varValue is not None:
        tree_totals[j] += p[i, j].varValue


plt.figure(figsize=(10, 6))
plt.bar([y+1 for y in Y], tree_totals)
plt.axhline(18000, color='red', linestyle='--', label="Target")
plt.xlabel("Year")
plt.ylabel("Total Trees Planted")
plt.title("Trees Planted per Year (HVI-Only Model, Obj. has linear hvi_weight and # of trees)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
yearly_deviation = sum(abs(tree_totals[j+1] - tree_totals[j]) for j in range(len(Y)-1))
print("Total year-to-year deviation:", yearly_deviation)
# Out:
# Total year-to-year deviation: 10000.0

# %%
high_hvi_counts = np.zeros(9)

for var in model4.variables():
    if var.name.startswith("x_") and var.varValue == 1:
        parts = var.name.split("_")
        tract_id = f"{parts[1]}_{parts[2]}"
        year = int(parts[3])  # 0-based year
        if tract_id in high_HVI_zones:
            high_hvi_counts[year] += 1

years = np.arange(1, 10)

plt.figure(figsize=(10, 6))
plt.bar(years, high_hvi_counts, color="tomato")
plt.xlabel("Year")
plt.ylabel("Number of High HVI Zones Assigned")
plt.title("High HVI Zone Assignments by Year (HVI-Only Model, Obj. has linear hvi_weight and # of trees)")
plt.xticks(years)
plt.grid(True, axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
print("Manual total high-HVI zones:", int(high_hvi_counts.sum()))
manual_high_hvi_tree_total = sum(p[i, j].varValue if hasattr(p[i, j], "varValue") else p[i, j]
                                 for (i, j) in p if i in high_HVI_zones)
print("Manual high-HVI tree total:", manual_high_hvi_tree_total)
# Out:
# Manual total high-HVI zones: 52
# Manual high-HVI tree total: 13285

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Extract assigned zones from model4
data = []

for var in model4.variables():
    if var.name.startswith("x_") and var.varValue == 1:
        # Parse variable name: x_{i}_{j}
        parts = var.name.split("_")
        i = "_".join(parts[1:-1])  # handle zone names with underscores
        j = int(parts[-1])
        hvi = hvi_scores[i]
        data.append({"Zone": i, "Year": j + 1, "HVI": hvi})

df = pd.DataFrame(data)

# Step 2: Count zones by Year and HVI (ensuring all HVI levels present)
hvi_levels = [1, 2, 3, 4, 5]
zone_counts = (
    df.groupby(["Year", "HVI"])
    .size()
    .unstack(fill_value=0)
    .reindex(columns=hvi_levels, fill_value=0)
)

# Step 3: Define color map
color_map = {
    1: "#1f77b4",  # blue
    2: "#2ca02c",  # green
    3: "#FFFF00",  # yellow
    4: "#ff7f0e",  # orange
    5: "#d62728",  # red
}
colors = [color_map[hvi] for hvi in hvi_levels]

# Step 4: Plot stacked bar chart
ax = zone_counts.plot(
    kind="bar",
    stacked=True,
    color=colors,
    figsize=(12, 6),
    edgecolor="black"
)

plt.title("Number of Zones by HVI Score per Year (HVI-Only Model, Obj. has linear hvi_weight and # of trees)")
plt.xlabel("Planning Year")
plt.ylabel("Number of Zones")
plt.xticks(rotation=0)
plt.legend(
    title="HVI Score",
    labels=[f"HVI {hvi}" for hvi in hvi_levels],
    bbox_to_anchor=(1.01, 1),
    loc='upper left'
)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a matrix to hold counts: rows = boroughs (5), cols = years (9)
borough_counts = np.zeros((5, 9))

# Go through the decision variables from the solved model
for var in model4.variables():  # or model3 if you're using that
    if var.name.startswith("x_") and var.varValue == 1:
        parts = var.name.split("_")
        tract_id = f"{parts[1]}_{parts[2]}"
        year = int(parts[3])  # 0-based

        if tract_id in community_boards:
            cb_code = community_boards[tract_id]
            borough = cb_code // 100  # Extract borough code (1–5)
            borough_counts[borough - 1, year] += 1  # Adjust for 0-index

# Plotting
years = np.arange(1, 10)  # 1–9
borough_labels = ["Manhattan", "Bronx", "Brooklyn", "Queens", "Staten Island"]
colors = ['#e41a1c', '#377eb8', '#4daf4a', '#984ea3', '#ff7f00']  # Distinct colors

plt.figure(figsize=(12, 7))
bottom = np.zeros(9)

# Stack each borough
for i in range(5):
    plt.bar(years, borough_counts[i], bottom=bottom, label=borough_labels[i], color=colors[i])
    bottom += borough_counts[i]

plt.xlabel("Year")
plt.ylabel("Number of Zones Assigned")
plt.title("Number of Zones Assigned per Year by Borough (HVI-Only Model, Obj. has linear hvi_weight and no # of trees)")
plt.xticks(years)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.legend(title="Borough")
plt.tight_layout()
plt.show()

# %%
total_model_trees = sum(p[i, j].varValue for i in I for j in Y if p[i, j].varValue is not None)
print("Total trees planted by model:", total_model_trees)

max_possible_trees = sum(planning_potentials[i] for i in I)
print("Max possible trees if no constraints:", max_possible_trees)
# Out:
# Total trees planted by model: 136926.0
# Max possible trees if no constraints: 138353

# %% [markdown]
# # **Current Solution**

# %%
x = {(i, j): LpVariable(f"x_{i}_{j}", cat="Binary") for i in I for j in Y}

  # p[i,j] is the # of trees planted in zone i in year j
p = {
    (i, j): LpVariable(f"p_{i}_{j}", lowBound=0, upBound=planning_potentials[i])
    for i in I for j in Y
}

manual_objective = 0

for unique_id, row in zones.iterrows():
    assigned_year = row["New Year Assignment"]
    num_trees = row["Planting Potential"]
    hvi = row["HVI"]

    if pd.notnull(assigned_year) and pd.notnull(num_trees):
        assigned_year = int(assigned_year) - 1

        for y in Y:
          x_val = 1 if y == assigned_year else 0
          p_val = num_trees if y == assigned_year else 0

          x[(unique_id, y)].setInitialValue(x_val)

          x[(unique_id, y)].varValue = x_val

          p[(unique_id, y)].setInitialValue(p_val)
          p[(unique_id, y)].varValue = p_val


        hvi_w = hvi_weight(hvi)
        time_w = time_weight(assigned_year)

        manual_objective += hvi_w * time_w * num_trees
        print(f"Census Tract: {unique_id} is assigned to Year: {assigned_year+1}, {int(num_trees)} trees to plant")

# Print total objective
print("\nManual assignment total objective value:", round(manual_objective, 2))

# Compare to model
from pulp import value
print("Model solution objective value:", round(value(model4.objective), 2))
# Out:
# Census Tract: 101_1 is assigned to Year: 8, 146 trees to plant
# Census Tract: 101_2 is assigned to Year: 2, 141 trees to plant
# Census Tract: 101_3 is assigned to Year: 2, 172 trees to plant
# Census Tract: 101_4 is assigned to Year: 5, 154 trees to plant
# Census Tract: 101_5 is assigned to Year: 8, 249 trees to plant
# Census Tract: 101_6 is assigned to Year: 5, 128 trees to plant
# Census Tract: 101_7 is assigned to Year: 5, 97 trees to plant
# Census Tract: 102_1 is assigned to Year: 8, 131 trees to plant
# Census Tract: 102_2 is assigned to Year: 2, 151 trees to plant
# Census Tract: 102_3 is assigned to Year: 5, 160 trees to plant
# Census Tract: 102_4 is assigned to Year: 5, 141 trees to plant
# Census Tract: 102_5 is assigned to Year: 5, 151 trees to plant
# Census Tract: 103_1 is assigned to Year: 8, 136 trees to plant
# Census Tract: 103_2 is assigned to Year: 5, 145 trees to plant
# Census Tract: 103_3 is assigned to Year: 2, 143 trees to plant
# Census Tract: 103_4 is assigned to Year: 2, 134 trees to plant
# Census Tract: 103_5 is assigned to Year: 5, 138 trees to plant
# Census Tract: 103_6 is assigned to Year: 7, 151 trees to plant
# Census Tract: 104_1 is assigned to Year: 6, 133 trees to plant
# Census Tract: 104_2 is assigned to Year: 9, 130 trees to plant
# Census Tract: 104_3 is assigned to Year: 9, 130 trees to plant
# Census Tract: 104_4 is assigned to Year: 3, 115 trees to plant
# Census Tract: 104_5 is assigned to Year: 3, 135 trees to plant
# Census Tract: 105_1 is assigned to Year: 1, 140 trees to plant
# Census Tract: 105_10 is assigned to Year: 4, 112 trees to plant
# Census Tract: 105_11 is assigned to Year: 7, 118 trees to plant
# Census Tract: 105_12 is assigned to Year: 7, 135 trees to plant
# Census Tract: 105_2 is assigned to Year: 1, 156 trees to plant
# Census Tract: 105_3 is assigned to Year: 1, 166 trees to plant
# Census Tract: 105_4 is assigned to Year: 1, 165 trees to plant
# Census Tract: 105_5 is assigned to Year: 4, 149 trees to plant
# Census Tract: 105_6 is assigned to Year: 4, 152 trees to plant
# Census Tract: 105_7 is assigned to Year: 4, 143 trees to plant
# Census Tract: 105_8 is assigned to Year: 7, 203 trees to plant
# Census Tract: 105_9 is assigned to Year: 7, 152 trees to plant
# Census Tract: 106_1 is assigned to Year: 1, 127 trees to plant
# Census Tract: 106_2 is assigned to Year: 1, 131 trees to plant
# Census Tract: 106_3 is assigned to Year: 4, 137 trees to plant
# Census Tract: 106_4 is assigned to Year: 4, 103 trees to plant
# Census Tract: 106_5 is assigned to Year: 7, 99 trees to plant
# Census Tract: 107_1 is assigned to Year: 1, 140 trees to plant
# Census Tract: 107_2 is assigned to Year: 4, 137 trees to plant
# Census Tract: 107_3 is assigned to Year: 7, 150 trees to plant
# Census Tract: 107_4 is assigned to Year: 2, 145 trees to plant
# Census Tract: 108_1 is assigned to Year: 3, 135 trees to plant
# Census Tract: 108_2 is assigned to Year: 9, 110 trees to plant
# Census Tract: 108_3 is assigned to Year: 6, 144 trees to plant
# Census Tract: 108_4 is assigned to Year: 9, 107 trees to plant
# Census Tract: 108_5 is assigned to Year: 6, 97 trees to plant
# Census Tract: 109_1 is assigned to Year: 5, 134 trees to plant
# Census Tract: 109_2 is assigned to Year: 2, 136 trees to plant
# Census Tract: 109_3 is assigned to Year: 8, 130 trees to plant
# Census Tract: 109_4 is assigned to Year: 8, 121 trees to plant
# Census Tract: 110_1 is assigned to Year: 8, 142 trees to plant
# Census Tract: 110_2 is assigned to Year: 5, 147 trees to plant
# Census Tract: 110_3 is assigned to Year: 2, 141 trees to plant
# Census Tract: 111_1 is assigned to Year: 3, 139 trees to plant
# Census Tract: 111_2 is assigned to Year: 9, 138 trees to plant
# Census Tract: 111_3 is assigned to Year: 6, 140 trees to plant
# Census Tract: 111_4 is assigned to Year: 3, 146 trees to plant
# Census Tract: 111_5 is assigned to Year: 6, 147 trees to plant
# Census Tract: 112_1 is assigned to Year: 9, 137 trees to plant
# Census Tract: 112_2 is assigned to Year: 9, 129 trees to plant
# Census Tract: 112_3 is assigned to Year: 3, 138 trees to plant
# Census Tract: 112_4 is assigned to Year: 3, 144 trees to plant
# Census Tract: 112_5 is assigned to Year: 3, 130 trees to plant
# Census Tract: 112_6 is assigned to Year: 6, 142 trees to plant
# Census Tract: 112_7 is assigned to Year: 6, 114 trees to plant
# Census Tract: 201_1 is assigned to Year: 6, 147 trees to plant
# Census Tract: 201_2 is assigned to Year: 9, 149 trees to plant
# Census Tract: 201_3 is assigned to Year: 3, 145 trees to plant
# Census Tract: 201_4 is assigned to Year: 3, 139 trees to plant
# Census Tract: 202_1 is assigned to Year: 7, 148 trees to plant
# Census Tract: 202_2 is assigned to Year: 3, 127 trees to plant
# Census Tract: 203_1 is assigned to Year: 9, 146 trees to plant
# Census Tract: 203_2 is assigned to Year: 6, 148 trees to plant
# Census Tract: 203_3 is assigned to Year: 6, 152 trees to plant
# Census Tract: 203_4 is assigned to Year: 3, 87 trees to plant
# Census Tract: 204_1 is assigned to Year: 9, 168 trees to plant
# Census Tract: 204_2 is assigned to Year: 3, 160 trees to plant
# Census Tract: 204_3 is assigned to Year: 9, 161 trees to plant
# Census Tract: 204_4 is assigned to Year: 6, 164 trees to plant
# Census Tract: 205_1 is assigned to Year: 2, 147 trees to plant
# Census Tract: 205_2 is assigned to Year: 8, 114 trees to plant
# Census Tract: 205_3 is assigned to Year: 5, 132 trees to plant
# Census Tract: 206_1 is assigned to Year: 2, 152 trees to plant
# Census Tract: 206_2 is assigned to Year: 8, 116 trees to plant
# Census Tract: 206_3 is assigned to Year: 5, 126 trees to plant
# Census Tract: 207_1 is assigned to Year: 8, 149 trees to plant
# Census Tract: 207_2 is assigned to Year: 5, 153 trees to plant
# Census Tract: 207_3 is assigned to Year: 5, 147 trees to plant
# Census Tract: 207_4 is assigned to Year: 2, 150 trees to plant
# Census Tract: 207_5 is assigned to Year: 2, 144 trees to plant
# Census Tract: 208_1 is assigned to Year: 4, 227 trees to plant
# Census Tract: 208_10 is assigned to Year: 7, 109 trees to plant
# Census Tract: 208_11 is assigned to Year: 7, 217 trees to plant
# Census Tract: 208_2 is assigned to Year: 7, 181 trees to plant
# Census Tract: 208_3 is assigned to Year: 4, 157 trees to plant
# Census Tract: 208_4 is assigned to Year: 1, 191 trees to plant
# Census Tract: 208_5 is assigned to Year: 7, 148 trees to plant
# Census Tract: 208_6 is assigned to Year: 7, 175 trees to plant
# Census Tract: 208_7 is assigned to Year: 1, 166 trees to plant
# Census Tract: 208_8 is assigned to Year: 4, 177 trees to plant
# Census Tract: 208_9 is assigned to Year: 1, 128 trees to plant
# Census Tract: 209_1 is assigned to Year: 8, 171 trees to plant
# Census Tract: 209_10 is assigned to Year: 8, 168 trees to plant
# Census Tract: 209_2 is assigned to Year: 5, 176 trees to plant
# Census Tract: 209_3 is assigned to Year: 2, 180 trees to plant
# Census Tract: 209_4 is assigned to Year: 2, 162 trees to plant
# Census Tract: 209_5 is assigned to Year: 8, 165 trees to plant
# Census Tract: 209_6 is assigned to Year: 2, 136 trees to plant
# Census Tract: 209_7 is assigned to Year: 5, 151 trees to plant
# Census Tract: 209_8 is assigned to Year: 2, 147 trees to plant
# Census Tract: 209_9 is assigned to Year: 5, 149 trees to plant
# Census Tract: 210_1 is assigned to Year: 5, 182 trees to plant
# Census Tract: 210_10 is assigned to Year: 8, 175 trees to plant
# Census Tract: 210_11 is assigned to Year: 8, 97 trees to plant
# Census Tract: 210_12 is assigned to Year: 2, 226 trees to plant
# Census Tract: 210_2 is assigned to Year: 5, 147 trees to plant
# Census Tract: 210_3 is assigned to Year: 5, 155 trees to plant
# Census Tract: 210_4 is assigned to Year: 5, 172 trees to plant
# Census Tract: 210_5 is assigned to Year: 2, 171 trees to plant
# Census Tract: 210_6 is assigned to Year: 2, 173 trees to plant
# Census Tract: 210_7 is assigned to Year: 8, 246 trees to plant
# Census Tract: 210_8 is assigned to Year: 8, 160 trees to plant
# Census Tract: 210_9 is assigned to Year: 2, 165 trees to plant
# Census Tract: 211_1 is assigned to Year: 1, 165 trees to plant
# Census Tract: 211_10 is assigned to Year: 4, 147 trees to plant
# Census Tract: 211_11 is assigned to Year: 7, 148 trees to plant
# Census Tract: 211_12 is assigned to Year: 7, 130 trees to plant
# Census Tract: 211_13 is assigned to Year: 1, 136 trees to plant
# Census Tract: 211_14 is assigned to Year: 4, 129 trees to plant
# Census Tract: 211_15 is assigned to Year: 1, 123 trees to plant
# Census Tract: 211_2 is assigned to Year: 1, 150 trees to plant
# Census Tract: 211_3 is assigned to Year: 4, 162 trees to plant
# Census Tract: 211_4 is assigned to Year: 5, 202 trees to plant
# Census Tract: 211_5 is assigned to Year: 4, 154 trees to plant
# Census Tract: 211_6 is assigned to Year: 4, 161 trees to plant
# Census Tract: 211_7 is assigned to Year: 7, 155 trees to plant
# Census Tract: 211_8 is assigned to Year: 7, 169 trees to plant
# Census Tract: 211_9 is assigned to Year: 3, 178 trees to plant
# Census Tract: 212_1 is assigned to Year: 6, 152 trees to plant
# Census Tract: 212_10 is assigned to Year: 1, 271 trees to plant
# Census Tract: 212_11 is assigned to Year: 6, 160 trees to plant
# Census Tract: 212_12 is assigned to Year: 6, 149 trees to plant
# Census Tract: 212_13 is assigned to Year: 9, 163 trees to plant
# Census Tract: 212_14 is assigned to Year: 9, 344 trees to plant
# Census Tract: 212_15 is assigned to Year: 9, 174 trees to plant
# Census Tract: 212_16 is assigned to Year: 9, 199 trees to plant
# Census Tract: 212_17 is assigned to Year: 6, 156 trees to plant
# Census Tract: 212_18 is assigned to Year: 9, 90 trees to plant
# Census Tract: 212_2 is assigned to Year: 3, 161 trees to plant
# Census Tract: 212_3 is assigned to Year: 3, 147 trees to plant
# Census Tract: 212_4 is assigned to Year: 3, 167 trees to plant
# Census Tract: 212_5 is assigned to Year: 9, 149 trees to plant
# Census Tract: 212_6 is assigned to Year: 6, 162 trees to plant
# Census Tract: 212_7 is assigned to Year: 1, 260 trees to plant
# Census Tract: 212_8 is assigned to Year: 6, 194 trees to plant
# Census Tract: 212_9 is assigned to Year: 3, 179 trees to plant
# Census Tract: 301_1 is assigned to Year: 6, 204 trees to plant
# Census Tract: 301_2 is assigned to Year: 6, 194 trees to plant
# Census Tract: 301_3 is assigned to Year: 6, 205 trees to plant
# Census Tract: 301_4 is assigned to Year: 3, 196 trees to plant
# Census Tract: 301_5 is assigned to Year: 3, 190 trees to plant
# Census Tract: 301_6 is assigned to Year: 9, 193 trees to plant
# Census Tract: 301_7 is assigned to Year: 9, 189 trees to plant
# Census Tract: 301_8 is assigned to Year: 9, 179 trees to plant
# Census Tract: 302_1 is assigned to Year: 7, 220 trees to plant
# Census Tract: 302_2 is assigned to Year: 7, 199 trees to plant
# Census Tract: 302_3 is assigned to Year: 7, 238 trees to plant
# Census Tract: 302_4 is assigned to Year: 1, 202 trees to plant
# Census Tract: 302_5 is assigned to Year: 4, 223 trees to plant
# Census Tract: 302_6 is assigned to Year: 1, 217 trees to plant
# Census Tract: 302_7 is assigned to Year: 4, 185 trees to plant
# Census Tract: 303_1 is assigned to Year: 6, 192 trees to plant
# Census Tract: 303_2 is assigned to Year: 9, 192 trees to plant
# Census Tract: 303_3 is assigned to Year: 3, 149 trees to plant
# Census Tract: 303_4 is assigned to Year: 3, 139 trees to plant
# Census Tract: 304_1 is assigned to Year: 6, 200 trees to plant
# Census Tract: 304_2 is assigned to Year: 3, 133 trees to plant
# Census Tract: 304_3 is assigned to Year: 9, 145 trees to plant
# Census Tract: 305_1 is assigned to Year: 8, 194 trees to plant
# Census Tract: 305_10 is assigned to Year: 8, 192 trees to plant
# Census Tract: 305_11 is assigned to Year: 4, 143 trees to plant
# Census Tract: 305_12 is assigned to Year: 8, 170 trees to plant
# Census Tract: 305_2 is assigned to Year: 4, 218 trees to plant
# Census Tract: 305_3 is assigned to Year: 1, 196 trees to plant
# Census Tract: 305_4 is assigned to Year: 1, 201 trees to plant
# Census Tract: 305_5 is assigned to Year: 1, 228 trees to plant
# Census Tract: 305_6 is assigned to Year: 8, 200 trees to plant
# Census Tract: 305_7 is assigned to Year: 4, 190 trees to plant
# Census Tract: 305_8 is assigned to Year: 5, 209 trees to plant
# Census Tract: 305_9 is assigned to Year: 8, 191 trees to plant
# Census Tract: 306_1 is assigned to Year: 1, 207 trees to plant
# Census Tract: 306_2 is assigned to Year: 4, 206 trees to plant
# Census Tract: 306_3 is assigned to Year: 1, 212 trees to plant
# Census Tract: 306_4 is assigned to Year: 7, 223 trees to plant
# Census Tract: 307_1 is assigned to Year: 3, 186 trees to plant
# Census Tract: 307_2 is assigned to Year: 3, 153 trees to plant
# Census Tract: 307_3 is assigned to Year: 6, 194 trees to plant
# Census Tract: 307_4 is assigned to Year: 9, 163 trees to plant
# Census Tract: 308_1 is assigned to Year: 6, 190 trees to plant
# Census Tract: 308_2 is assigned to Year: 3, 139 trees to plant
# Census Tract: 308_3 is assigned to Year: 9, 129 trees to plant
# Census Tract: 309_1 is assigned to Year: 3, 190 trees to plant
# Census Tract: 309_2 is assigned to Year: 9, 183 trees to plant
# Census Tract: 309_3 is assigned to Year: 6, 183 trees to plant
# Census Tract: 310_1 is assigned to Year: 2, 198 trees to plant
# Census Tract: 310_2 is assigned to Year: 5, 194 trees to plant
# Census Tract: 310_3 is assigned to Year: 5, 209 trees to plant
# Census Tract: 310_4 is assigned to Year: 2, 194 trees to plant
# Census Tract: 310_5 is assigned to Year: 5, 206 trees to plant
# Census Tract: 310_6 is assigned to Year: 8, 197 trees to plant
# Census Tract: 310_7 is assigned to Year: 8, 196 trees to plant
# Census Tract: 310_8 is assigned to Year: 2, 194 trees to plant
# Census Tract: 311_1 is assigned to Year: 9, 207 trees to plant
# Census Tract: 311_10 is assigned to Year: 6, 183 trees to plant
# Census Tract: 311_2 is assigned to Year: 9, 198 trees to plant
# Census Tract: 311_3 is assigned to Year: 3, 222 trees to plant
# Census Tract: 311_4 is assigned to Year: 3, 215 trees to plant
# Census Tract: 311_5 is assigned to Year: 7, 205 trees to plant
# Census Tract: 311_6 is assigned to Year: 6, 216 trees to plant
# Census Tract: 311_7 is assigned to Year: 6, 215 trees to plant
# Census Tract: 311_8 is assigned to Year: 9, 213 trees to plant
# Census Tract: 311_9 is assigned to Year: 7, 225 trees to plant
# Census Tract: 312_1 is assigned to Year: 3, 202 trees to plant
# Census Tract: 312_2 is assigned to Year: 3, 195 trees to plant
# Census Tract: 312_3 is assigned to Year: 9, 201 trees to plant
# Census Tract: 312_4 is assigned to Year: 3, 206 trees to plant
# Census Tract: 312_5 is assigned to Year: 6, 201 trees to plant
# Census Tract: 312_6 is assigned to Year: 6, 195 trees to plant
# Census Tract: 312_7 is assigned to Year: 9, 203 trees to plant
# Census Tract: 313_1 is assigned to Year: 7, 215 trees to plant
# Census Tract: 313_2 is assigned to Year: 7, 205 trees to plant
# Census Tract: 313_3 is assigned to Year: 4, 191 trees to plant
# Census Tract: 313_4 is assigned to Year: 4, 189 trees to plant
# Census Tract: 313_5 is assigned to Year: 4, 194 trees to plant
# Census Tract: 313_6 is assigned to Year: 1, 233 trees to plant
# Census Tract: 313_7 is assigned to Year: 1, 212 trees to plant
# Census Tract: 314_1 is assigned to Year: 9, 191 trees to plant
# Census Tract: 314_2 is assigned to Year: 3, 192 trees to plant
# Census Tract: 314_3 is assigned to Year: 3, 147 trees to plant
# Census Tract: 314_4 is assigned to Year: 6, 171 trees to plant
# Census Tract: 314_5 is assigned to Year: 6, 207 trees to plant
# Census Tract: 314_6 is assigned to Year: 9, 159 trees to plant
# Census Tract: 315_1 is assigned to Year: 5, 800 trees to plant
# Census Tract: 315_10 is assigned to Year: 5, 207 trees to plant
# Census Tract: 315_11 is assigned to Year: 8, 124 trees to plant
# Census Tract: 315_12 is assigned to Year: 5, 130 trees to plant
# Census Tract: 315_13 is assigned to Year: 8, 128 trees to plant
# Census Tract: 315_2 is assigned to Year: 8, 220 trees to plant
# Census Tract: 315_3 is assigned to Year: 2, 205 trees to plant
# Census Tract: 315_4 is assigned to Year: 2, 205 trees to plant
# Census Tract: 315_5 is assigned to Year: 8, 193 trees to plant
# Census Tract: 315_6 is assigned to Year: 2, 189 trees to plant
# Census Tract: 315_7 is assigned to Year: 8, 232 trees to plant
# Census Tract: 315_8 is assigned to Year: 7, 191 trees to plant
# Census Tract: 315_9 is assigned to Year: 7, 203 trees to plant
# Census Tract: 316_1 is assigned to Year: 2, 162 trees to plant
# Census Tract: 316_2 is assigned to Year: 5, 190 trees to plant
# Census Tract: 316_3 is assigned to Year: 8, 152 trees to plant
# Census Tract: 317_1 is assigned to Year: 8, 191 trees to plant
# Census Tract: 317_2 is assigned to Year: 8, 209 trees to plant
# Census Tract: 317_3 is assigned to Year: 5, 189 trees to plant
# Census Tract: 317_4 is assigned to Year: 5, 203 trees to plant
# Census Tract: 317_5 is assigned to Year: 2, 198 trees to plant
# Census Tract: 317_6 is assigned to Year: 2, 198 trees to plant
# Census Tract: 317_7 is assigned to Year: 2, 191 trees to plant
# Census Tract: 317_8 is assigned to Year: 5, 186 trees to plant
# Census Tract: 318_1 is assigned to Year: 2, 216 trees to plant
# Census Tract: 318_10 is assigned to Year: 1, 243 trees to plant
# Census Tract: 318_11 is assigned to Year: 1, 211 trees to plant
# Census Tract: 318_12 is assigned to Year: 4, 243 trees to plant
# Census Tract: 318_13 is assigned to Year: 2, 204 trees to plant
# Census Tract: 318_14 is assigned to Year: 4, 221 trees to plant
# Census Tract: 318_15 is assigned to Year: 4, 221 trees to plant
# Census Tract: 318_16 is assigned to Year: 4, 220 trees to plant
# Census Tract: 318_17 is assigned to Year: 1, 159 trees to plant
# Census Tract: 318_18 is assigned to Year: 7, 211 trees to plant
# Census Tract: 318_2 is assigned to Year: 2, 217 trees to plant
# Census Tract: 318_3 is assigned to Year: 2, 202 trees to plant
# Census Tract: 318_4 is assigned to Year: 7, 226 trees to plant
# Census Tract: 318_5 is assigned to Year: 1, 211 trees to plant
# Census Tract: 318_6 is assigned to Year: 7, 196 trees to plant
# Census Tract: 318_7 is assigned to Year: 7, 221 trees to plant
# Census Tract: 318_8 is assigned to Year: 1, 228 trees to plant
# Census Tract: 318_9 is assigned to Year: 1, 231 trees to plant
# Census Tract: 401_1 is assigned to Year: 2, 540 trees to plant
# Census Tract: 401_2 is assigned to Year: 8, 546 trees to plant
# Census Tract: 401_3 is assigned to Year: 5, 542 trees to plant
# Census Tract: 401_4 is assigned to Year: 2, 402 trees to plant
# Census Tract: 401_5 is assigned to Year: 5, 423 trees to plant
# Census Tract: 402_1 is assigned to Year: 7, 553 trees to plant
# Census Tract: 402_2 is assigned to Year: 1, 562 trees to plant
# Census Tract: 402_3 is assigned to Year: 4, 494 trees to plant
# Census Tract: 402_4 is assigned to Year: 1, 500 trees to plant
# Census Tract: 403_1 is assigned to Year: 8, 643 trees to plant
# Census Tract: 403_2 is assigned to Year: 5, 621 trees to plant
# Census Tract: 403_3 is assigned to Year: 2, 620 trees to plant
# Census Tract: 403_4 is assigned to Year: 2, 531 trees to plant
# Census Tract: 404_1 is assigned to Year: 1, 609 trees to plant
# Census Tract: 404_2 is assigned to Year: 4, 635 trees to plant
# Census Tract: 404_3 is assigned to Year: 7, 596 trees to plant
# Census Tract: 404_4 is assigned to Year: 1, 544 trees to plant
# Census Tract: 405_1 is assigned to Year: 6, 562 trees to plant
# Census Tract: 405_2 is assigned to Year: 3, 589 trees to plant
# Census Tract: 405_3 is assigned to Year: 2, 579 trees to plant
# Census Tract: 405_4 is assigned to Year: 9, 562 trees to plant
# Census Tract: 405_5 is assigned to Year: 9, 555 trees to plant
# Census Tract: 405_6 is assigned to Year: 8, 546 trees to plant
# Census Tract: 405_7 is assigned to Year: 6, 564 trees to plant
# Census Tract: 405_8 is assigned to Year: 3, 568 trees to plant
# Census Tract: 406_1 is assigned to Year: 3, 547 trees to plant
# Census Tract: 406_2 is assigned to Year: 6, 538 trees to plant
# Census Tract: 406_3 is assigned to Year: 6, 473 trees to plant
# Census Tract: 406_4 is assigned to Year: 9, 422 trees to plant
# Census Tract: 407_1 is assigned to Year: 3, 558 trees to plant
# Census Tract: 407_10 is assigned to Year: 3, 541 trees to plant
# Census Tract: 407_11 is assigned to Year: 2, 603 trees to plant
# Census Tract: 407_2 is assigned to Year: 6, 544 trees to plant
# Census Tract: 407_3 is assigned to Year: 6, 569 trees to plant
# Census Tract: 407_4 is assigned to Year: 9, 550 trees to plant
# Census Tract: 407_5 is assigned to Year: 9, 453 trees to plant
# Census Tract: 407_6 is assigned to Year: 5, 577 trees to plant
# Census Tract: 407_7 is assigned to Year: 5, 552 trees to plant
# Census Tract: 407_8 is assigned to Year: 8, 600 trees to plant
# Census Tract: 407_9 is assigned to Year: 8, 669 trees to plant
# Census Tract: 408_1 is assigned to Year: 2, 558 trees to plant
# Census Tract: 408_10 is assigned to Year: 8, 590 trees to plant
# Census Tract: 408_2 is assigned to Year: 9, 627 trees to plant
# Census Tract: 408_3 is assigned to Year: 2, 567 trees to plant
# Census Tract: 408_4 is assigned to Year: 5, 542 trees to plant
# Census Tract: 408_5 is assigned to Year: 5, 657 trees to plant
# Census Tract: 408_6 is assigned to Year: 6, 641 trees to plant
# Census Tract: 408_7 is assigned to Year: 6, 505 trees to plant
# Census Tract: 408_8 is assigned to Year: 9, 602 trees to plant
# Census Tract: 408_9 is assigned to Year: 8, 630 trees to plant
# Census Tract: 409_1 is assigned to Year: 3, 542 trees to plant
# Census Tract: 409_2 is assigned to Year: 4, 556 trees to plant
# Census Tract: 409_3 is assigned to Year: 9, 556 trees to plant
# Census Tract: 409_4 is assigned to Year: 7, 571 trees to plant
# Census Tract: 409_5 is assigned to Year: 1, 542 trees to plant
# Census Tract: 409_6 is assigned to Year: 7, 535 trees to plant
# Census Tract: 413_7 is assigned to Year: 9, 626 trees to plant
# Census Tract: 413_8 is assigned to Year: 6, 563 trees to plant
# Census Tract: 413_9 is assigned to Year: 6, 690 trees to plant
# Census Tract: 414_1 is assigned to Year: 6, 597 trees to plant
# Census Tract: 414_2 is assigned to Year: 7, 625 trees to plant
# Census Tract: 414_3 is assigned to Year: 7, 685 trees to plant
# Census Tract: 414_4 is assigned to Year: 5, 652 trees to plant
# Census Tract: 414_5 is assigned to Year: 4, 569 trees to plant
# Census Tract: 414_6 is assigned to Year: 1, 587 trees to plant
# Census Tract: 501_1 is assigned to Year: 3, 1220 trees to plant
# Census Tract: 501_2 is assigned to Year: 6, 1191 trees to plant
# Census Tract: 501_3 is assigned to Year: 8, 1259 trees to plant
# Census Tract: 501_4 is assigned to Year: 4, 1168 trees to plant
# Census Tract: 501_5 is assigned to Year: 7, 1211 trees to plant
# Census Tract: 501_6 is assigned to Year: 9, 1149 trees to plant
# Census Tract: 501_7 is assigned to Year: 5, 1292 trees to plant
# Census Tract: 502_1 is assigned to Year: 5, 1343 trees to plant
# Census Tract: 502_2 is assigned to Year: 9, 1507 trees to plant
# Census Tract: 502_3 is assigned to Year: 2, 1576 trees to plant
# Census Tract: 502_4 is assigned to Year: 1, 1258 trees to plant
# Census Tract: 502_5 is assigned to Year: 4, 1167 trees to plant
# Census Tract: 502_6 is assigned to Year: 8, 1186 trees to plant
# Census Tract: 502_7 is assigned to Year: 3, 833 trees to plant
# Census Tract: 503_1 is assigned to Year: 6, 1196 trees to plant
# Census Tract: 503_2 is assigned to Year: 3, 1302 trees to plant
# Census Tract: 503_3 is assigned to Year: 2, 1295 trees to plant
# Census Tract: 503_4 is assigned to Year: 1, 1224 trees to plant
# Census Tract: 503_5 is assigned to Year: 7, 1260 trees to plant
# Census Tract: 503_6 is assigned to Year: 4, 1147 trees to plant
#
# Manual assignment total objective value: 313914.07
# Model solution objective value: 346073.36

# %%
assignments = []
for i in I:
    for j in Y:
        var = x[i,j]
        if var.varValue is not None and var.varValue > 0.5:  # assigned
            assignments.append((i, j, hvi_scores[i]))

df_assign = pd.DataFrame(assignments, columns=['Tract', 'Year', 'HVI'])

hvi_per_year = df_assign.groupby('Year')['HVI'].sum().reset_index()
hvi_per_year['Year_adj'] = hvi_per_year['Year'] + 1
plt.figure(figsize=(10,6))
plt.bar(hvi_per_year['Year_adj'], hvi_per_year['HVI'], color='orange', alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Total Heat Vulnerability Index (HVI)')
plt.title('Total HVI Impact From Census Tracts Assigned per Year (Current Solution)')
plt.xticks(hvi_per_year['Year_adj'])
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
zones_per_year = np.zeros(9)
for (i, j), var in x.items():
    if var.varValue is not None and var.varValue > 0.5:
        zones_per_year[j - 1] += 1  # Adjust because years are 1-indexed

for i in I:
  if x[i,8].varValue == 1:
    zones_per_year[8] += 1

years = list(range(1, 10))
plt.bar(years, zones_per_year, color='blue', alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Number of Zones Assigned')
plt.title('Number of Zones Assigned to Each Year (Current Solution)')
plt.xticks(years)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
high_hvi_counts = np.zeros(len(Y))

for (i,j), var in x.items():
    if var.name.startswith("x_") and var.varValue == 1:
        parts = var.name.split("_")
        i = "_".join(parts[1:-1])  # zone ID
        j = int(parts[-1])         # year index

        if hvi_scores[i] >= 4:
            high_hvi_counts[j] += 1

years = np.arange(1, 10)

plt.figure(figsize=(10, 6))
plt.bar(years, high_hvi_counts, color="tomato")
plt.xlabel("Year")
plt.ylabel("Number of High HVI Zones Assigned")
plt.title("High HVI Zone Assignments by Year (Current Solution)")
plt.xticks(years)
plt.grid(True, axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
high_hvi_zone_ids = [i for i, score in hvi_scores.items() if score >= 4]
print(f"Total high-HVI zones: {len(high_hvi_zone_ids)}")
# Out:
# Total high-HVI zones: 82

# %%
tree_totals = np.zeros(len(Y))
for (i, j), var in x.items():
    if var.varValue == 1:
        tree_totals[j] += p[(i, j)].varValue

plt.figure(figsize=(10, 6))
plt.bar([y+1 for y in Y], tree_totals)
plt.axhline(18000, color='red', linestyle='--', label="Target")
plt.xlabel("Year")
plt.ylabel("Total Trees Planted")
plt.title("Trees Planted per Year (Current Solution)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
hvi_tree_volume = np.zeros(9)

for (i, j), var in p.items():
    if hvi_scores[i] >= 4 and var.varValue:
        hvi_tree_volume[j] += var.varValue

plt.figure(figsize=(10, 6))
plt.bar(years, hvi_tree_volume, color="seagreen")
plt.xlabel("Year")
plt.ylabel("Trees Planted in High-HVI Zones")
plt.title("High HVI Tree Volume by Year")
plt.grid(True, axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialize a matrix: borough_counts[borough][year] = number of zones
borough_counts = np.zeros((5, 9), dtype=int)  # 5 boroughs, 9 years

for (tract_id, year), val in x.items():
    assigned = val.varValue if hasattr(val, "varValue") else val
    if assigned == 1:
        borough = community_boards[tract_id] // 100
        borough_counts[borough - 1, int(year) - 1] += 1  # Ensure year is int and adjust to 0-index

# Plotting
years = np.arange(1, 10)  # Year labels 1–9
colors = ['#e41a1c', '#377eb8', '#4daf4a', '#984ea3', '#ff7f00']
labels = ["Manhattan", "Bronx", "Brooklyn", "Queens", "Staten Island"]

plt.figure(figsize=(12, 7))
bottom = np.zeros(9)

for b in range(5):
    plt.bar(years, borough_counts[b], bottom=bottom, color=colors[b], label=labels[b])
    bottom += borough_counts[b]

plt.xlabel('Year')
plt.ylabel('Number of Zones')
plt.title('Number of Zones Assigned per Borough Each Year (Current Solution)')
plt.xticks(years)
plt.legend(title="Borough")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
from pulp import LpConstraint, LpConstraintEQ, LpConstraintLE

violations = []

# 1. Each tract must be scheduled exactly once
for i in I:
    total = sum(round(x[(i, j)].varValue or 0) for j in Y)
    if abs(total - 1) > 1e-2:
      # print(f"Debug: {i} assignment total = {total}")
      # for j in Y:
      #   print(f"  Year {j+1}: x = {x[(i,j)].varValue}")
      violations.append(f"Zone {i} assigned {total} times.")

# 2. CB-Year tree capacity constraint (≤ 1299 trees per CB per year)
for cb in set(community_boards.values()):
    cb_tracts = [i for i in I if community_boards[i] == cb]
    for j in Y:
        total_trees = sum(p[(i, j)].varValue for i in cb_tracts)
        if total_trees > 1299 + 1e-5:
            violations.append(f"CB {cb}, Year {j+1}: {total_trees:.2f} trees (limit: 1299)")

# 3. Trees only planted if tract is assigned that year
for i in I:
    for j in Y:
        if p[(i, j)].varValue > planning_potentials[i] * x[(i, j)].varValue + 1e-5:
            violations.append(f"Inconsistent planting: Tract {i}, Year {j}")

# 4. Visit at least one CT in each CB every 3 years (in blocks)
for cb in set(community_boards.values()):
    cb_tracts = [i for i in I if community_boards[i] == cb]
    if len(cb_tracts) > 2:
        for start in [0, 3, 6]:
            total = sum(x[(i, j)].varValue for i in cb_tracts for j in range(start, start + 3))
            if total < 1 - 1e-5:
                violations.append(f"CB {cb}: No zones visited in years {start + 1}–{start + 3}")
    else:
        total = sum(x[(i, j)].varValue for i in cb_tracts for j in Y)
        if abs(total - len(cb_tracts)) > 1e-5:
            violations.append(f"CB {cb}: Expected {len(cb_tracts)} visits, got {total}")

if violations:
    print("⚠️ Constraint violations found:")
    for v in violations:
        print(" -", v)
else:
    print("✅ All constraints satisfied by fixed solution.")
# Out:
# ⚠️ Constraint violations found:
#  - CB 412, Year 1: 1580.00 trees (limit: 1299)
#  - CB 413, Year 1: 1713.00 trees (limit: 1299)
#  - CB 414, Year 7: 1310.00 trees (limit: 1299)
#  - CB 502, Year 2: 1576.00 trees (limit: 1299)
#  - CB 502, Year 5: 1343.00 trees (limit: 1299)
#  - CB 502, Year 9: 1507.00 trees (limit: 1299)
#  - CB 503, Year 3: 1302.00 trees (limit: 1299)

# %%
# Step 1: Extract assigned zones from model4
data = []

for var in model4.variables():
    if var.name.startswith("x_") and var.varValue == 1:
        # Parse variable name: x_{i}_{j}
        parts = var.name.split("_")
        i = "_".join(parts[1:-1])  # handle zone names with underscores
        j = int(parts[-1])
        hvi = hvi_scores[i]
        data.append({"Zone": i, "Year": j + 1, "HVI": hvi})

df = pd.DataFrame(data)

df['HVI_bin'] = df['HVI'].round().astype(int)

# Now define discrete levels based on the rounded values present
hvi_levels = sorted(df['HVI_bin'].unique())

zone_counts = (
    df.groupby(['Year', 'HVI_bin'])
    .size()
    .unstack(fill_value=0)
    .reindex(columns=hvi_levels, fill_value=0)
)

# Adjust color_map for the actual hvi_levels
color_map = {
    1: "#1f77b4",  # blue
    2: "#2ca02c",  # green
    3: "#FFFF00",  # yellow
    4: "#ff7f0e",  # orange
    5: "#d62728",  # red
}
colors = [color_map.get(hvi, "#888888") for hvi in hvi_levels]  # default gray if missing

# Plot as before
ax = zone_counts.plot(
    kind="bar",
    stacked=True,
    color=colors,
    figsize=(12, 6),
    edgecolor="black"
)

plt.title("Number of Zones by Rounded HVI Score per Year (Current Solution)")
plt.xlabel("Planning Year")
plt.ylabel("Number of Zones")
plt.xticks(rotation=0)
plt.legend(
    title="HVI Score",
    labels=[f"HVI {hvi}" for hvi in hvi_levels],
    bbox_to_anchor=(1.01, 1),
    loc='upper left'
)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()
